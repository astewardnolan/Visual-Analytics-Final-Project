# %% [markdown]
# # Line Graphs for Median Sales Price by City

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reading in the data
df = pd.read_csv('MedianSalesPricesforCities.csv')
df
# Out:
#                            Metropolitan Area   2021   2022   2023  Unnamed: 4  \
# 0                Seattle-Tacoma-Bellevue, WA  698.6  756.2  735.0         NaN
# 1        Los Angeles-Long Beach-Glendale, CA  801.3  849.4  833.4         NaN
# 2      New York-Newark-Jersey City, NY-NJ-PA  561.0  607.6  636.9         NaN
# 3         Chicago-Naperville-Elgin, IL-IN-WI  330.4  345.6  351.2         NaN
# 4             Boston-Cambridge-Newton, MA-NH  642.2  685.6  714.0         NaN
# 5       Houston-The Woodlands-Sugar Land, TX  304.1  345.0  340.3         NaN
# 6  Miami-Fort Lauderdale-West Palm Beach, FL  480.0  557.5  593.0         NaN
#
#    Unnamed: 5
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN

# %%
# Dropping unneccessary columns
df = df.drop(columns=['Unnamed: 4', 'Unnamed: 5'])
df
# Out:
#                            Metropolitan Area   2021   2022   2023
# 0                Seattle-Tacoma-Bellevue, WA  698.6  756.2  735.0
# 1        Los Angeles-Long Beach-Glendale, CA  801.3  849.4  833.4
# 2      New York-Newark-Jersey City, NY-NJ-PA  561.0  607.6  636.9
# 3         Chicago-Naperville-Elgin, IL-IN-WI  330.4  345.6  351.2
# 4             Boston-Cambridge-Newton, MA-NH  642.2  685.6  714.0
# 5       Houston-The Woodlands-Sugar Land, TX  304.1  345.0  340.3
# 6  Miami-Fort Lauderdale-West Palm Beach, FL  480.0  557.5  593.0

# %%
# df = df.set_index('Metropolitan Area')
# df

# %% [markdown]
# ## Seattle:

# %%
# Extract the row where the 'Metropolitan' row equals 'Seattle'
seattle = df.loc[df['Metropolitan Area'] == 'Seattle-Tacoma-Bellevue, WA']
print(seattle)
# Out:
#              Metropolitan Area   2021   2022   2023
# 0  Seattle-Tacoma-Bellevue, WA  698.6  756.2  735.0

# %%
x_seattle = seattle.columns[1:]  # Years (ignores 'Metropolitan Area')
y_seattle = seattle.iloc[0, 1:]  # Values (row values from 2021 onwards)
print(x_seattle)
print(y_seattle)
# Out:
# Index(['2021', '2022', '2023'], dtype='object')
# 2021    698.6
# 2022    756.2
# 2023    735.0
# Name: 0, dtype: object

# %%
# # Plotting the seattle data from the df
# # type(row)
# plt.plot(seattle['Metropolitan Area'], seattle['DATE'], marker='o', color='#40c9cd')
# plt.xlabel('Median Sales Price')
# plt.ylabel('Year')
# plt.title("Median Sales Price of a Home in Seattle by Year")
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 # Plotting the seattle data from the df
#       2 # type(row)
# ----> 3 plt.plot(seattle['SEAT653PCPI'], seattle['DATE'], marker='o', color='#40c9cd')
#       4 plt.xlabel('Per-Capita Income')
#       5 plt.ylabel('Year')
#
# NameError: name 'seattle' is not defined

# %%
plt.plot(x_seattle, y_seattle, marker='o', color='#40c9cd')
plt.title('Median Sales Price for Seattle-Tacoma-Bellevue, WA')
plt.xlabel('Year')
plt.ylabel('Median Sales Price (in Thousands)')
# plt.grid(True)
plt.show()

# %% [markdown]
# ## LA:

# %%
# Extract the row where the 'Metropolitan' row equals 'LA'
la = df.loc[df['Metropolitan Area'] == 'Los Angeles-Long Beach-Glendale, CA']
print(la)
# Out:
#                      Metropolitan Area   2021   2022   2023
# 1  Los Angeles-Long Beach-Glendale, CA  801.3  849.4  833.4

# %%
x_la = la.columns[1:]  # Years (ignores 'Metropolitan Area')
y_la = la.iloc[0, 1:]  # Values (row values from 2021 onwards)
print(x_la)
print(y_la)
# Out:
# Index(['2021', '2022', '2023'], dtype='object')
# 2021    801.3
# 2022    849.4
# 2023    833.4
# Name: 1, dtype: object

# %%
plt.plot(x_la, y_la, marker='o', color='darkblue')
plt.title('Median Sales Price for Los Angeles-Long Beach-Glendale, CA')
plt.xlabel('Year')
plt.ylabel('Median Sales Price (in Thousands)')
# plt.grid(True)
plt.show()

# %% [markdown]
# ## NYC:

# %%
nyc = df.loc[df['Metropolitan Area'] == 'New York-Newark-Jersey City, NY-NJ-PA']
print(nyc)
# Out:
#                        Metropolitan Area   2021   2022   2023
# 2  New York-Newark-Jersey City, NY-NJ-PA  561.0  607.6  636.9

# %%
x_nyc = nyc.columns[1:]  # Years (ignores 'Metropolitan Area')
y_nyc = nyc.iloc[0, 1:]  # Values (row values from 2021 onwards)
print(x_nyc)
print(y_nyc)
# Out:
# Index(['2021', '2022', '2023'], dtype='object')
# 2021    561.0
# 2022    607.6
# 2023    636.9
# Name: 2, dtype: object

# %%
plt.plot(x_nyc, y_nyc, marker='o', color='#b8b9b8')
plt.title('Median Sales Price for New York-Newark-Jersey City, NY-NJ-PA')
plt.xlabel('Year')
plt.ylabel('Median Sales Price (in Thousands)')
# plt.grid(True)
plt.show()

# %% [markdown]
# ## Chicago:

# %%
chicago = df.loc[df['Metropolitan Area'] == 'Chicago-Naperville-Elgin, IL-IN-WI']
print(chicago)
# Out:
#                     Metropolitan Area   2021   2022   2023
# 3  Chicago-Naperville-Elgin, IL-IN-WI  330.4  345.6  351.2

# %%
x_chicago = chicago.columns[1:]  # Years (ignores 'Metropolitan Area')
y_chicago = chicago.iloc[0, 1:]  # Values (row values from 2021 onwards)
print(x_chicago)
print(y_chicago)
# Out:
# Index(['2021', '2022', '2023'], dtype='object')
# 2021    330.4
# 2022    345.6
# 2023    351.2
# Name: 3, dtype: object

# %%
plt.plot(x_chicago, y_chicago, marker='o', color='#66aff0')
plt.title('Median Sales Price for Chicago-Naperville-Elgin, IL-IN-WI')
plt.xlabel('Year')
plt.ylabel('Median Sales Price (in Thousands)')
# plt.grid(True)
plt.show()

# %% [markdown]
# ## Boston:

# %%
boston = df.loc[df['Metropolitan Area'] == 'Boston-Cambridge-Newton, MA-NH']
print(boston)
# Out:
#                 Metropolitan Area   2021   2022   2023
# 4  Boston-Cambridge-Newton, MA-NH  642.2  685.6  714.0

# %%
x_boston = boston.columns[1:]  # Years (ignores 'Metropolitan Area')
y_boston = boston.iloc[0, 1:]  # Values (row values from 2021 onwards)
print(x_boston)
print(y_boston)
# Out:
# Index(['2021', '2022', '2023'], dtype='object')
# 2021    642.2
# 2022    685.6
# 2023    714.0
# Name: 4, dtype: object

# %%
plt.plot(x_boston, y_boston, marker='o', color='#c62205')
plt.title('Median Sales Price for Boston-Cambridge-Newton, MA-NH')
plt.xlabel('Year')
plt.ylabel('Median Sales Price (in Thousands)')
# plt.grid(True)
plt.show()

# %% [markdown]
# ## Houston:

# %%
houston = df.loc[df['Metropolitan Area'] == 'Houston-The Woodlands-Sugar Land, TX']
print(houston)
# Out:
#                       Metropolitan Area   2021   2022   2023
# 5  Houston-The Woodlands-Sugar Land, TX  304.1  345.0  340.3

# %%
x_houston = houston.columns[1:]  # Years (ignores 'Metropolitan Area')
y_houston = houston.iloc[0, 1:]  # Values (row values from 2021 onwards)
print(x_houston)
print(y_houston)
# Out:
# Index(['2021', '2022', '2023'], dtype='object')
# 2021    304.1
# 2022    345.0
# 2023    340.3
# Name: 5, dtype: object

# %%
plt.plot(x_houston, y_houston, marker='o', color='darkblue')
plt.title('Median Sales Price for Houston-The Woodlands-Sugar Land, TX')
plt.xlabel('Year')
plt.ylabel('Median Sales Price (in Thousands)')
# plt.grid(True)
plt.show()

# %% [markdown]
# ## Miami:

# %%
miami = df.loc[df['Metropolitan Area'] == 'Miami-Fort Lauderdale-West Palm Beach, FL']
print(miami)
# Out:
#                            Metropolitan Area   2021   2022   2023
# 6  Miami-Fort Lauderdale-West Palm Beach, FL  480.0  557.5  593.0

# %%
x_miami = miami.columns[1:]  # Years (ignores 'Metropolitan Area')
y_miami = miami.iloc[0, 1:]  # Values (row values from 2021 onwards)
print(x_miami)
print(y_miami)
# Out:
# Index(['2021', '2022', '2023'], dtype='object')
# 2021    480.0
# 2022    557.5
# 2023    593.0
# Name: 6, dtype: object

# %%
plt.plot(x_miami, y_miami, marker='o', color='#ff73ce')
plt.title('Median Sales Price for Miami-Fort Lauderdale-West Palm Beach, FL')
plt.xlabel('Year')
plt.ylabel('Median Sales Price (in Thousands)')
# plt.grid(True)
plt.show()
